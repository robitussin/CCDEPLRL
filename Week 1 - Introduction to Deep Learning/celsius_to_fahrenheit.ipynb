# %% [markdown]
# # The Basics: Training Your First Model

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l02c01_celsius_to_fahrenheit.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l02c01_celsius_to_fahrenheit.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# Welcome to this Colab where you will train your first Machine Learning model!
#
# We'll try to keep things simple here, and only introduce basic concepts. Later Colabs will cover more advanced problems.
#
# The problem we will solve is to convert from Celsius to Fahrenheit, where the approximate formula is:
#
# $$ f = c \times 1.8 + 32 $$
#
#
# Of course, it would be simple enough to create a conventional Python function that directly performs this calculation, but that wouldn't be machine learning.
#
#
# Instead, we will give TensorFlow some sample Celsius values (0, 8, 15, 22, 38) and their corresponding Fahrenheit values (32, 46, 59, 72, 100).
# Then, we will train a model that figures out the above formula through the training process.

# %% [markdown]
# ## Import dependencies
#
# First, import TensorFlow. Here, we're calling it `tf` for ease of use. We also tell it to only display errors.
#
# Next, import [NumPy](http://www.numpy.org/) as `np`. Numpy helps us to represent our data as highly performant lists.

# %%
import tensorflow as tf

# %%
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# ## Set up training data
#
# As we saw before, supervised Machine Learning is all about figuring out an algorithm given a set of inputs and outputs. Since the task in this Codelab is to create a model that can give the temperature in Fahrenheit when given the degrees in Celsius, we create two lists `celsius_q` and `fahrenheit_a` that we can use to train our model.

# %%
celsius_q    = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit_a = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

for i,c in enumerate(celsius_q):
  print("{} degrees Celsius = {} degrees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees Celsius = -40.0 degrees Fahrenheit
# -10.0 degrees Celsius = 14.0 degrees Fahrenheit
# 0.0 degrees Celsius = 32.0 degrees Fahrenheit
# 8.0 degrees Celsius = 46.0 degrees Fahrenheit
# 15.0 degrees Celsius = 59.0 degrees Fahrenheit
# 22.0 degrees Celsius = 72.0 degrees Fahrenheit
# 38.0 degrees Celsius = 100.0 degrees Fahrenheit

# %% [markdown]
# ### Some Machine Learning terminology
#
#  - **Feature** — The input(s) to our model. In this case, a single value — the degrees in Celsius.
#
#  - **Labels** — The output our model predicts. In this case, a single value — the degrees in Fahrenheit.
#
#  - **Example** — A pair of inputs/outputs used during training. In our case a pair of values from `celsius_q` and `fahrenheit_a` at a specific index, such as `(22,72)`.

# %% [markdown]
# ## Create the model
#
# Next, create the model. We will use the simplest possible model we can, a Dense network. Since the problem is straightforward, this network will require only a single layer, with a single neuron.
#
# ### Build a layer
#
# We'll call the layer `l0` and create it by instantiating `tf.keras.layers.Dense` with the following configuration:
#
# *   `input_shape=[1]` — This specifies that the input to this layer is a single value. That is, the shape is a one-dimensional array with one member. Since this is the first (and only) layer, that input shape is the input shape of the entire model. The single value is a floating point number, representing degrees Celsius.
#
# *   `units=1` — This specifies the number of neurons in the layer. The number of neurons defines how many internal variables the layer has to try to learn how to solve the problem (more later). Since this is the final layer, it is also the size of the model's output — a single float value representing degrees Fahrenheit. (In a multi-layered network, the size and shape of the layer would need to match the `input_shape` of the next layer.)

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %% [markdown]
# ### Assemble layers into the model
#
# Once layers are defined, they need to be assembled into a model. The Sequential model definition takes a list of layers as an argument, specifying the calculation order from the input to the output.
#
# This model has just a single layer, l0.

# %%
model = tf.keras.Sequential([l0])

# %% [markdown]
# **Note**
#
# You will often see the layers defined inside the model definition, rather than beforehand:
#
# ```python
# model = tf.keras.Sequential([
#   tf.keras.layers.Dense(units=1, input_shape=[1])
# ])
# ```

# %% [markdown]
# ## Compile the model, with loss and optimizer functions
#
# Before training, the model has to be compiled. When compiled for training, the model is given:
#
# - **Loss function** — A way of measuring how far off predictions are from the desired outcome. (The measured difference is called the "loss".)
#
# - **Optimizer function** — A way of adjusting internal values in order to reduce the loss.

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %% [markdown]
# These are used during training (`model.fit()`, below) to first calculate the loss at each point, and then improve it. In fact, the act of calculating the current loss of a model and then improving it is precisely what training is.
#
# During training, the optimizer function is used to calculate adjustments to the model's internal variables. The goal is to adjust the internal variables until the model (which is really a math function) mirrors the actual equation for converting Celsius to Fahrenheit.
#
# TensorFlow uses numerical analysis to perform this tuning, and all this complexity is hidden from you so we will not go into the details here. What is useful to know about these parameters are:
#
# The loss function ([mean squared error](https://en.wikipedia.org/wiki/Mean_squared_error)) and the optimizer ([Adam](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/)) used here are standard for simple models like this one, but many others are available. It is not important to know how these specific functions work at this point.
#
# One part of the Optimizer you may need to think about when building your own models is the learning rate (`0.1` in the code above). This is the step size taken when adjusting values in the model. If the value is too small, it will take too many iterations to train the model. Too large, and accuracy goes down. Finding a good value often involves some trial and error, but the range is usually within 0.001 (default), and 0.1

# %% [markdown]
# ## Train the model
#
# Train the model by calling the `fit` method.
#
# During training, the model takes in Celsius values, performs a calculation using the current internal variables (called "weights") and outputs values which are meant to be the Fahrenheit equivalent. Since the weights are initially set randomly, the output will not be close to the correct value. The difference between the actual output and the desired output is calculated using the loss function, and the optimizer function directs how the weights should be adjusted.
#
# This cycle of calculate, compare, adjust is controlled by the `fit` method. The first argument is the inputs, the second argument is the desired outputs. The `epochs` argument specifies how many times this cycle should be run, and the `verbose` argument controls how much output the method produces.

# %%
history = model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=1)
print("Finished training the model")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 21ms/step - loss: 11.7333
# Epoch 2/500
# 1/1 [==============================] - 0s 24ms/step - loss: 11.5869
# Epoch 3/500
# 1/1 [==============================] - 0s 18ms/step - loss: 11.4422
# Epoch 4/500
# 1/1 [==============================] - 0s 14ms/step - loss: 11.2991
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 11.1576
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 11.0177
# Epoch 7/500
# 1/1 [==============================] - 0s 31ms/step - loss: 10.8794
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 10.7427
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 10.6076
# Epoch 10/500
# 1/1 [==============================] - 0s 14ms/step - loss: 10.4739
# Epoch 11/500
# 1/1 [==============================] - 0s 18ms/step - loss: 10.3418
# Epoch 12/500
# 1/1 [==============================] - 0s 15ms/step - loss: 10.2113
# Epoch 13/500
# 1/1 [==============================] - 0s 30ms/step - loss: 10.0822
# Epoch 14/500
# 1/1 [==============================] - 0s 15ms/step - loss: 9.9545
# Epoch 15/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.8284
# Epoch 16/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.7037
# Epoch 17/500
# 1/1 [==============================] - 0s 16ms/step - loss: 9.5804
# Epoch 18/500
# 1/1 [==============================] - 0s 21ms/step - loss: 9.4586
# Epoch 19/500
# 1/1 [==============================] - 0s 22ms/step - loss: 9.3381
# Epoch 20/500
# 1/1 [==============================] - 0s 23ms/step - loss: 9.2191
# Epoch 21/500
# 1/1 [==============================] - 0s 25ms/step - loss: 9.1014
# Epoch 22/500
# 1/1 [==============================] - 0s 23ms/step - loss: 8.9851
# Epoch 23/500
# 1/1 [==============================] - 0s 24ms/step - loss: 8.8702
# Epoch 24/500
# 1/1 [==============================] - 0s 25ms/step - loss: 8.7566
# Epoch 25/500
# 1/1 [==============================] - 0s 26ms/step - loss: 8.6443
# Epoch 26/500
# 1/1 [==============================] - 0s 18ms/step - loss: 8.5333
# Epoch 27/500
# 1/1 [==============================] - 0s 19ms/step - loss: 8.4236
# Epoch 28/500
# 1/1 [==============================] - 0s 19ms/step - loss: 8.3152
# Epoch 29/500
# 1/1 [==============================] - 0s 19ms/step - loss: 8.2081
# Epoch 30/500
# 1/1 [==============================] - 0s 18ms/step - loss: 8.1022
# Epoch 31/500
# 1/1 [==============================] - 0s 23ms/step - loss: 7.9976
# Epoch 32/500
# 1/1 [==============================] - 0s 20ms/step - loss: 7.8942
# Epoch 33/500
# 1/1 [==============================] - 0s 29ms/step - loss: 7.7921
# Epoch 34/500
# 1/1 [==============================] - 0s 25ms/step - loss: 7.6911
# Epoch 35/500
# 1/1 [==============================] - 0s 16ms/step - loss: 7.5913
# Epoch 36/500
# 1/1 [==============================] - 0s 11ms/step - loss: 7.4927
# Epoch 37/500
# 1/1 [==============================] - 0s 12ms/step - loss: 7.3953
# Epoch 38/500
# 1/1 [==============================] - 0s 16ms/step - loss: 7.2991
# Epoch 39/500
# 1/1 [==============================] - 0s 12ms/step - loss: 7.2039
# Epoch 40/500
# 1/1 [==============================] - 0s 23ms/step - loss: 7.1100
# Epoch 41/500
# 1/1 [==============================] - 0s 50ms/step - loss: 7.0171
# Epoch 42/500
# 1/1 [==============================] - 0s 22ms/step - loss: 6.9254
# Epoch 43/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.8347
# Epoch 44/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.7452
# Epoch 45/500
# 1/1 [==============================] - 0s 21ms/step - loss: 6.6567
# Epoch 46/500
# 1/1 [==============================] - 0s 14ms/step - loss: 6.5692
# Epoch 47/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.4829
# Epoch 48/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.3975
# Epoch 49/500
# 1/1 [==============================] - 0s 31ms/step - loss: 6.3133
# Epoch 50/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.2300
# Epoch 51/500
# 1/1 [==============================] - 0s 22ms/step - loss: 6.1477
# Epoch 52/500
# 1/1 [==============================] - 0s 22ms/step - loss: 6.0664
# Epoch 53/500
# 1/1 [==============================] - 0s 14ms/step - loss: 5.9861
# Epoch 54/500
# 1/1 [==============================] - 0s 31ms/step - loss: 5.9068
# Epoch 55/500
# 1/1 [==============================] - 0s 18ms/step - loss: 5.8285
# Epoch 56/500
# 1/1 [==============================] - 0s 17ms/step - loss: 5.7511
# Epoch 57/500
# 1/1 [==============================] - 0s 36ms/step - loss: 5.6746
# Epoch 58/500
# 1/1 [==============================] - 0s 22ms/step - loss: 5.5991
# Epoch 59/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.5246
# Epoch 60/500
# 1/1 [==============================] - 0s 16ms/step - loss: 5.4509
# Epoch 61/500
# 1/1 [==============================] - 0s 31ms/step - loss: 5.3781
# Epoch 62/500
# 1/1 [==============================] - 0s 22ms/step - loss: 5.3063
# Epoch 63/500
# 1/1 [==============================] - 0s 19ms/step - loss: 5.2353
# Epoch 64/500
# 1/1 [==============================] - 0s 19ms/step - loss: 5.1652
# Epoch 65/500
# 1/1 [==============================] - 0s 21ms/step - loss: 5.0960
# Epoch 66/500
# 1/1 [==============================] - 0s 19ms/step - loss: 5.0276
# Epoch 67/500
# 1/1 [==============================] - 0s 27ms/step - loss: 4.9600
# Epoch 68/500
# 1/1 [==============================] - 0s 21ms/step - loss: 4.8933
# Epoch 69/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8275
# Epoch 70/500
# 1/1 [==============================] - 0s 31ms/step - loss: 4.7624
# Epoch 71/500
# 1/1 [==============================] - 0s 27ms/step - loss: 4.6982
# Epoch 72/500
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6348
# Epoch 73/500
# 1/1 [==============================] - 0s 24ms/step - loss: 4.5721
# Epoch 74/500
# 1/1 [==============================] - 0s 23ms/step - loss: 4.5103
# Epoch 75/500
# 1/1 [==============================] - 0s 16ms/step - loss: 4.4492
# Epoch 76/500
# 1/1 [==============================] - 0s 14ms/step - loss: 4.3889
# Epoch 77/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.3293
# Epoch 78/500
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2705
# Epoch 79/500
# 1/1 [==============================] - 0s 14ms/step - loss: 4.2124
# Epoch 80/500
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1551
# Epoch 81/500
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0985
# Epoch 82/500
# 1/1 [==============================] - 0s 17ms/step - loss: 4.0426
# Epoch 83/500
# 1/1 [==============================] - 0s 25ms/step - loss: 3.9874
# Epoch 84/500
# 1/1 [==============================] - 0s 26ms/step - loss: 3.9329
# Epoch 85/500
# 1/1 [==============================] - 0s 34ms/step - loss: 3.8791
# Epoch 86/500
# 1/1 [==============================] - 0s 31ms/step - loss: 3.8260
# Epoch 87/500
# 1/1 [==============================] - 0s 25ms/step - loss: 3.7736
# Epoch 88/500
# 1/1 [==============================] - 0s 16ms/step - loss: 3.7218
# Epoch 89/500
# 1/1 [==============================] - 0s 35ms/step - loss: 3.6707
# Epoch 90/500
# 1/1 [==============================] - 0s 34ms/step - loss: 3.6203
# Epoch 91/500
# 1/1 [==============================] - 0s 21ms/step - loss: 3.5705
# Epoch 92/500
# 1/1 [==============================] - 0s 33ms/step - loss: 3.5213
# Epoch 93/500
# 1/1 [==============================] - 0s 36ms/step - loss: 3.4728
# Epoch 94/500
# 1/1 [==============================] - 0s 17ms/step - loss: 3.4249
# Epoch 95/500
# 1/1 [==============================] - 0s 38ms/step - loss: 3.3776
# Epoch 96/500
# 1/1 [==============================] - 0s 34ms/step - loss: 3.3310
# Epoch 97/500
# 1/1 [==============================] - 0s 21ms/step - loss: 3.2849
# Epoch 98/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2394
# Epoch 99/500
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1945
# Epoch 100/500
# 1/1 [==============================] - 0s 23ms/step - loss: 3.1502
# Epoch 101/500
# 1/1 [==============================] - 0s 27ms/step - loss: 3.1065
# Epoch 102/500
# 1/1 [==============================] - 0s 33ms/step - loss: 3.0633
# Epoch 103/500
# 1/1 [==============================] - 0s 30ms/step - loss: 3.0207
# Epoch 104/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9787
# Epoch 105/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9372
# Epoch 106/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8963
# Epoch 107/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8559
# Epoch 108/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8160
# Epoch 109/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7766
# Epoch 110/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7378
# Epoch 111/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6995
# Epoch 112/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6616
# Epoch 113/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6243
# Epoch 114/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.5875
# Epoch 115/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5511
# Epoch 116/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5153
# Epoch 117/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4799
# Epoch 118/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4450
# Epoch 119/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4105
# Epoch 120/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3765
# Epoch 121/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3430
# Epoch 122/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3099
# Epoch 123/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2772
# Epoch 124/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2450
# Epoch 125/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2133
# Epoch 126/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1819
# Epoch 127/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1510
# Epoch 128/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1205
# Epoch 129/500
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0904
# Epoch 130/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0607
# Epoch 131/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0314
# Epoch 132/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0025
# Epoch 133/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9740
# Epoch 134/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9459
# Epoch 135/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9182
# Epoch 136/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8908
# Epoch 137/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8638
# Epoch 138/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8372
# Epoch 139/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8109
# Epoch 140/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7851
# Epoch 141/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7595
# Epoch 142/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7343
# Epoch 143/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.7095
# Epoch 144/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6850
# Epoch 145/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6608
# Epoch 146/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6370
# Epoch 147/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6135
# Epoch 148/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5903
# Epoch 149/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5675
# Epoch 150/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5449
# Epoch 151/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5227
# Epoch 152/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5008
# Epoch 153/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4792
# Epoch 154/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4579
# Epoch 155/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4369
# Epoch 156/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4162
# Epoch 157/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3957
# Epoch 158/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3756
# Epoch 159/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3557
# Epoch 160/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3361
# Epoch 161/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3168
# Epoch 162/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2978
# Epoch 163/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2790
# Epoch 164/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2605
# Epoch 165/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2423
# Epoch 166/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2243
# Epoch 167/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2066
# Epoch 168/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1891
# Epoch 169/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1719
# Epoch 170/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1549
# Epoch 171/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1382
# Epoch 172/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1217
# Epoch 173/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1054
# Epoch 174/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0894
# Epoch 175/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0735
# Epoch 176/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0580
# Epoch 177/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0426
# Epoch 178/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0275
# Epoch 179/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0126
# Epoch 180/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9979
# Epoch 181/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9834
# Epoch 182/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9691
# Epoch 183/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9550
# Epoch 184/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9411
# Epoch 185/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9275
# Epoch 186/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9140
# Epoch 187/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9007
# Epoch 188/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8876
# Epoch 189/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8747
# Epoch 190/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8620
# Epoch 191/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8495
# Epoch 192/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8372
# Epoch 193/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8250
# Epoch 194/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8130
# Epoch 195/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8012
# Epoch 196/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7896
# Epoch 197/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7782
# Epoch 198/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7669
# Epoch 199/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7557
# Epoch 200/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7448
# Epoch 201/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7340
# Epoch 202/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7233
# Epoch 203/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7129
# Epoch 204/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7025
# Epoch 205/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6924
# Epoch 206/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6823
# Epoch 207/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6725
# Epoch 208/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6628
# Epoch 209/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6532
# Epoch 210/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6437
# Epoch 211/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6344
# Epoch 212/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6253
# Epoch 213/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6163
# Epoch 214/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6074
# Epoch 215/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5986
# Epoch 216/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5900
# Epoch 217/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5815
# Epoch 218/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5732
# Epoch 219/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5649
# Epoch 220/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5568
# Epoch 221/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5488
# Epoch 222/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5410
# Epoch 223/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5332
# Epoch 224/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5256
# Epoch 225/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5181
# Epoch 226/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5107
# Epoch 227/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5034
# Epoch 228/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4962
# Epoch 229/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4891
# Epoch 230/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4822
# Epoch 231/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4753
# Epoch 232/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4686
# Epoch 233/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4619
# Epoch 234/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4554
# Epoch 235/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4490
# Epoch 236/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4426
# Epoch 237/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4364
# Epoch 238/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4302
# Epoch 239/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4242
# Epoch 240/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4182
# Epoch 241/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4123
# Epoch 242/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4066
# Epoch 243/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4009
# Epoch 244/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3953
# Epoch 245/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3898
# Epoch 246/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3843
# Epoch 247/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3790
# Epoch 248/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3737
# Epoch 249/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3686
# Epoch 250/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3635
# Epoch 251/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3585
# Epoch 252/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3535
# Epoch 253/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3487
# Epoch 254/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3439
# Epoch 255/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3392
# Epoch 256/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3346
# Epoch 257/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3300
# Epoch 258/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3255
# Epoch 259/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3211
# Epoch 260/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3167
# Epoch 261/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3125
# Epoch 262/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3082
# Epoch 263/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3041
# Epoch 264/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3000
# Epoch 265/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2960
# Epoch 266/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2921
# Epoch 267/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2882
# Epoch 268/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2844
# Epoch 269/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2806
# Epoch 270/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2769
# Epoch 271/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2733
# Epoch 272/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2697
# Epoch 273/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2661
# Epoch 274/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2627
# Epoch 275/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2593
# Epoch 276/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2559
# Epoch 277/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2526
# Epoch 278/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2493
# Epoch 279/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2461
# Epoch 280/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2430
# Epoch 281/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2399
# Epoch 282/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2369
# Epoch 283/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2339
# Epoch 284/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2309
# Epoch 285/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2280
# Epoch 286/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2252
# Epoch 287/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2223
# Epoch 288/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2196
# Epoch 289/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2169
# Epoch 290/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2142
# Epoch 291/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2116
# Epoch 292/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2090
# Epoch 293/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2065
# Epoch 294/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2040
# Epoch 295/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2015
# Epoch 296/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1991
# Epoch 297/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1967
# Epoch 298/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1944
# Epoch 299/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1921
# Epoch 300/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1898
# Epoch 301/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1876
# Epoch 302/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1854
# Epoch 303/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1832
# Epoch 304/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1811
# Epoch 305/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1790
# Epoch 306/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1770
# Epoch 307/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1750
# Epoch 308/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1730
# Epoch 309/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1711
# Epoch 310/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1691
# Epoch 311/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1673
# Epoch 312/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1654
# Epoch 313/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1636
# Epoch 314/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1618
# Epoch 315/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1600
# Epoch 316/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1583
# Epoch 317/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1566
# Epoch 318/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1549
# Epoch 319/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1533
# Epoch 320/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1517
# Epoch 321/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1501
# Epoch 322/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1485
# Epoch 323/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1470
# Epoch 324/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1455
# Epoch 325/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1440
# Epoch 326/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1426
# Epoch 327/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1411
# Epoch 328/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1397
# Epoch 329/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1383
# Epoch 330/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1370
# Epoch 331/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1356
# Epoch 332/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1343
# Epoch 333/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1330
# Epoch 334/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1318
# Epoch 335/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1305
# Epoch 336/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1293
# Epoch 337/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1281
# Epoch 338/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1269
# Epoch 339/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1257
# Epoch 340/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1246
# Epoch 341/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1235
# Epoch 342/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1224
# Epoch 343/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1213
# Epoch 344/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1202
# Epoch 345/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1192
# Epoch 346/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1181
# Epoch 347/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1171
# Epoch 348/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1161
# Epoch 349/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1152
# Epoch 350/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1142
# Epoch 351/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1133
# Epoch 352/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1123
# Epoch 353/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1114
# Epoch 354/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1105
# Epoch 355/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1097
# Epoch 356/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1088
# Epoch 357/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1079
# Epoch 358/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1071
# Epoch 359/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1063
# Epoch 360/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1055
# Epoch 361/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1047
# Epoch 362/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1039
# Epoch 363/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1032
# Epoch 364/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1024
# Epoch 365/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1017
# Epoch 366/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1010
# Epoch 367/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1002
# Epoch 368/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0995
# Epoch 369/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0989
# Epoch 370/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0982
# Epoch 371/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0975
# Epoch 372/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0969
# Epoch 373/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0962
# Epoch 374/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0956
# Epoch 375/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0950
# Epoch 376/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0944
# Epoch 377/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0938
# Epoch 378/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0932
# Epoch 379/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0927
# Epoch 380/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0921
# Epoch 381/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0915
# Epoch 382/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0910
# Epoch 383/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0905
# Epoch 384/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0900
# Epoch 385/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0894
# Epoch 386/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0889
# Epoch 387/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0884
# Epoch 388/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0880
# Epoch 389/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0875
# Epoch 390/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0870
# Epoch 391/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0866
# Epoch 392/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0861
# Epoch 393/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0857
# Epoch 394/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0852
# Epoch 395/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0848
# Epoch 396/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0844
# Epoch 397/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0840
# Epoch 398/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0836
# Epoch 399/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0832
# Epoch 400/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0828
# Epoch 401/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0824
# Epoch 402/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0820
# Epoch 403/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0817
# Epoch 404/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0813
# Epoch 405/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0810
# Epoch 406/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0806
# Epoch 407/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0803
# Epoch 408/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0799
# Epoch 409/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0796
# Epoch 410/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0793
# Epoch 411/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0790
# Epoch 412/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0786
# Epoch 413/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0783
# Epoch 414/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0780
# Epoch 415/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0778
# Epoch 416/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0775
# Epoch 417/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0772
# Epoch 418/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0769
# Epoch 419/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0766
# Epoch 420/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0764
# Epoch 421/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0761
# Epoch 422/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0758
# Epoch 423/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0756
# Epoch 424/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0753
# Epoch 425/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0751
# Epoch 426/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0749
# Epoch 427/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0746
# Epoch 428/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0744
# Epoch 429/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0742
# Epoch 430/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0740
# Epoch 431/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0737
# Epoch 432/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0735
# Epoch 433/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0733
# Epoch 434/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0731
# Epoch 435/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0729
# Epoch 436/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0727
# Epoch 437/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0725
# Epoch 438/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0723
# Epoch 439/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0721
# Epoch 440/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0720
# Epoch 441/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0718
# Epoch 442/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0716
# Epoch 443/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0714
# Epoch 444/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0713
# Epoch 445/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0711
# Epoch 446/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0709
# Epoch 447/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0708
# Epoch 448/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0706
# Epoch 449/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0705
# Epoch 450/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0703
# Epoch 451/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0702
# Epoch 452/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0700
# Epoch 453/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0699
# Epoch 454/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0698
# Epoch 455/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0696
# Epoch 456/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0695
# Epoch 457/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0693
# Epoch 458/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0692
# Epoch 459/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0691
# Epoch 460/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0690
# Epoch 461/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0689
# Epoch 462/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0687
# Epoch 463/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0686
# Epoch 464/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0685
# Epoch 465/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0684
# Epoch 466/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0683
# Epoch 467/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0682
# Epoch 468/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0681
# Epoch 469/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0680
# Epoch 470/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0679
# Epoch 471/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0678
# Epoch 472/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0677
# Epoch 473/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0676
# Epoch 474/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0675
# Epoch 475/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0674
# Epoch 476/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0673
# Epoch 477/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0672
# Epoch 478/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0671
# Epoch 479/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0670
# Epoch 480/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0670
# Epoch 481/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0669
# Epoch 482/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0668
# Epoch 483/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0667
# Epoch 484/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0666
# Epoch 485/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0666
# Epoch 486/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0665
# Epoch 487/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0664
# Epoch 488/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0663
# Epoch 489/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0663
# Epoch 490/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0662
# Epoch 491/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0661
# Epoch 492/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0661
# Epoch 493/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0660
# Epoch 494/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0660
# Epoch 495/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0659
# Epoch 496/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0658
# Epoch 497/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0658
# Epoch 498/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0657
# Epoch 499/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0657
# Epoch 500/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0656
# Finished training the model

# %% [markdown]
# In later videos, we will go into more detail on what actually happens here and how a Dense layer actually works internally.

# %% [markdown]
# ## Display training statistics
#
# The `fit` method returns a history object. We can use this object to plot how the loss of our model goes down after each training epoch. A high loss means that the Fahrenheit degrees the model predicts is far from the corresponding value in `fahrenheit_a`.
#
# We'll use [Matplotlib](https://matplotlib.org/) to visualize this (you could use another tool). As you can see, our model improves very quickly at first, and then has a steady, slow improvement until it is very near "perfect" towards the end.

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## Use the model to predict values
#
# Now you have a model that has been trained to learn the relationship between `celsius_q` and `fahrenheit_a`. You can use the predict method to have it calculate the Fahrenheit degrees for a previously unknown Celsius degrees.
#
# So, for example, if the Celsius value is 100, what do you think the Fahrenheit result will be? Take a guess before you run this code.

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 91ms/step
# [[211.28233]]

# %% [markdown]
# The correct answer is $100 \times 1.8 + 32 = 212$, so our model is doing really well.
#
# ### To review
#
#
# *   We created a model with a Dense layer
# *   We trained it with 3500 examples (7 pairs, over 500 epochs).
#
# Our model tuned the variables (weights) in the Dense layer until it was able to return the correct Fahrenheit value for any Celsius value. (Remember, 100 Celsius was not part of our training data.)

# %% [markdown]
# ## Looking at the layer weights
#
# Finally, let's print the internal variables of the Dense layer.

# %%
print("These are the layer variables: {}".format(l0.get_weights()))
# Out:
# These are the layer variables: [array([[1.8294007]], dtype=float32), array([28.334156], dtype=float32)]

# %% [markdown]
# The first variable is close to ~1.8 and the second to ~32. These values (1.8 and 32) are the actual variables in the real conversion formula.
#
# This is really close to the values in the conversion formula. We'll explain this in an upcoming video where we show how a Dense layer works, but for a single neuron with a single input and a single output, the internal math looks the same as [the equation for a line](https://en.wikipedia.org/wiki/Linear_equation#Slope%E2%80%93intercept_form), $y = mx + b$, which has the same form as the conversion equation, $f = 1.8c + 32$.
#
# Since the form is the same, the variables should converge on the standard values of 1.8 and 32, which is exactly what happened.
#
# With additional neurons, additional inputs, and additional outputs, the formula becomes much more complex, but the idea is the same.
#
# ### A little experiment
#
# Just for fun, what if we created more Dense layers with different units, which therefore also has more variables?

# %%
l0 = tf.keras.layers.Dense(units=4, input_shape=[1])
l1 = tf.keras.layers.Dense(units=4)
l2 = tf.keras.layers.Dense(units=1)
model = tf.keras.Sequential([l0, l1, l2])
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))
model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
print(model.predict([100.0]))
print("Model predicts that 100 degrees Celsius is: {} degrees Fahrenheit".format(model.predict([100.0])))
print("These are the l0 variables: {}".format(l0.get_weights()))
print("These are the l1 variables: {}".format(l1.get_weights()))
print("These are the l2 variables: {}".format(l2.get_weights()))
# Out:
# Finished training the model
# 1/1 [==============================] - 0s 97ms/step
# [[211.74742]]
# 1/1 [==============================] - 0s 50ms/step
# Model predicts that 100 degrees Celsius is: [[211.74742]] degrees Fahrenheit
# These are the l0 variables: [array([[ 0.37555304, -0.20036146,  0.49555138, -0.08606204]],
#       dtype=float32), array([3.401936 , 1.0228474, 3.7680519, 1.2509637], dtype=float32)]
# These are the l1 variables: [array([[-1.0608958 , -0.9313362 , -0.8770066 , -1.0729177 ],
#        [ 0.02344553, -0.16447072, -0.8554343 , -0.02311401],
#        [-0.01877563, -0.7122818 ,  0.05854186, -1.2744416 ],
#        [ 0.66906506, -0.3836643 , -0.5376911 , -0.33798555]],
#       dtype=float32), array([-2.0702763, -3.1827252, -3.4491823, -3.606167 ], dtype=float32)]
# These are the l2 variables: [array([[-0.18062638],
#        [-0.79712737],
#        [-0.72462565],
#        [-1.144676  ]], dtype=float32), array([3.413885], dtype=float32)]

# %% [markdown]
# As you can see, this model is also able to predict the corresponding Fahrenheit value really well. But when you look at the variables (weights) in the `l0` and `l1` layers, they are nothing even close to ~1.8 and ~32. The added complexity hides the "simple" form of the conversion equation.
